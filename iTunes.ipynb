# %% [markdown]
# ### ITUNES API

# %%
base_url = "https://itunes.apple.com/search"

# %%
import requests

# %% [markdown]
# PASAR PARÁMETROS USANDO GET METHOD

# %%
r = requests.get(base_url, params = {"term": "nirvana", "country": "us", "limit": 200})
r.url
# Out:
# 'https://itunes.apple.com/search?term=nirvana&country=us&limit=200'

# %%
import json
info = r.json()
print(json.dumps(info, indent = 4))
# Out:
# {
#     "resultCount": 200,
#     "results": [
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 112018,
#             "collectionId": 1413920644,
#             "trackId": 1413921155,
#             "artistName": "Nirvana",
#             "collectionName": "Nirvana",
#             "trackName": "Smells Like Teen Spirit",
#             "collectionCensoredName": "Nirvana",
#             "trackCensoredName": "Smells Like Teen Spirit",
#             "artistViewUrl": "https://music.apple.com/us/artist/nirvana/112018?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/smells-like-teen-spirit/1413920644?i=1413921155&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/smells-like-teen-spirit/1413920644?i=1413921155&uo=4",
# ...

# %%
info.keys()
info['results'][0]['trackName']
# Out:
# 'Smells Like Teen Spirit'

# %%
info['results'][0]['releaseDate']
# Out:
# '1991-09-10T12:00:00Z'

# %%
import pandas as pd

# %%
data_frame = pd.DataFrame(info['results'])
data_frame
# Out:
#     wrapperType  kind  artistId  collectionId     trackId artistName  \
# 0         track  song    112018    1413920644  1413921155    Nirvana
# 1         track  song    112018    1413920644  1413921156    Nirvana
# 2         track  song    112018    1413920644  1413921158    Nirvana
# 3         track  song    112018    1413920644  1413921237    Nirvana
# 4         track  song    112018    1440858699  1440859612    Nirvana
# ..          ...   ...       ...           ...         ...        ...
# 195       track  song    112018    1440778637  1440779990    Nirvana
# 196       track  song    112018    1440778637  1440779386    Nirvana
# 197       track  song    112018    1440778637  1440779410    Nirvana
# 198       track  song    112018    1440778637  1440779405    Nirvana
# 199       track  song    150548    1028833323  1028833324   The Cult
#
#                                collectionName                trackName  \
# ...
